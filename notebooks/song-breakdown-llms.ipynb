# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)

# %%
file_path_dict = "../data/audio_features_data_dictionary.csv"
dict_df = pd.read_csv(file_path_dict)
dict_df
# Out:
#              Feature                                            Meaning  \
# 0       Danceability  How suitable a track is for dancing, based on ...
# 1             Energy  Intensity and activity of a track. High energy...
# 2                Key  Estimated musical key (pitch center) of the song.
# 3           Loudness        Overall loudness measured in decibels (dB).
# 4               Mode             Major or minor scale mode of the song.
# 5        Speechiness              Measure of spoken words in the track.
# 6       Acousticness                  Confidence the track is acoustic.
# 7   Instrumentalness              Predicts if track contains no vocals.
# 8           Liveness  Detects presence of an audience or live record...
# 9            Valence        Musical positiveness conveyed by the track.
# 10             Tempo     Estimated beats per minute (BPM) of the track.
# 11     Duration (ms)             Duration of the track in milliseconds.
#
# ...

# %%
file_path_sample = "../data/raw/audio_features_sample.csv"
sample_df = pd.read_csv(file_path_sample)
sample_df
# Out:
#           Song Title                          Artist  Danceability  Energy  \
# 0       Uptown Funk!    Mark Ronson feat. Bruno Mars          0.84    0.80
# 1  Thinking Out Loud                      Ed Sheeran          0.72    0.56
# 2      See You Again  Wiz Khalifa feat. Charlie Puth          0.66    0.55
# 3         Trap Queen                       Fetty Wap          0.82    0.68
# 4              Sugar                        Maroon 5          0.76    0.74
#
#    Key  Loudness  Mode  Speechiness  Acousticness  Instrumentalness  Liveness  \
# 0    5      -5.5     0         0.05          0.19               0.0      0.35
# 1    0      -6.9     1         0.03          0.53               0.0      0.08
# 2    2      -6.4     1         0.05          0.41               0.0      0.11
# 3    1      -4.8     0         0.14          0.13               0.0      0.38
# 4    0      -4.3     1         0.04          0.10               0.0      0.15
#
#    Valence  Tempo  Duration (ms)
# ...

# %%
file_path_full = "../data/raw/full_audio_features.csv"
full_df = pd.read_csv(file_path_full)
full_df
# Out:
#                                   Song Title  \
# 0                               Uptown Funk!
# 1                          Thinking Out Loud
# 2                              See You Again
# 3                                 Trap Queen
# 4                                      Sugar
# 5                          Shut Up and Dance
# 6                                Blank Space
# 7                    Watch Me (Whip/Nae Nae)
# 8                                  Earned It
# 9                                  The Hills
# 10                             Love Yourself
# 11                                     Sorry
# 12                                 One Dance
# 13                                      Work
# 14                              Stressed Out
# 15                                     Panda
# 16                                     Hello
# 17                         Don't Let Me Down
# 18                   Can't Stop the Feeling!
# 19                                    Closer
# ...
